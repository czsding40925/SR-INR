# %% [markdown]
# ## Apply Layerwise Successive Refinement
# * Train a model with shallow layers (1)
# * Freeze the weights, add the layer and train again (2, 3, ...)
# * For future, after each training, do SuRP

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd /content/drive/Othercomputers/My MacBook Pro/Projects/SR-INR
# !pip install pytorch_msssim
# Out:
# Mounted at /content/drive
# /content/drive/Othercomputers/My MacBook Pro/Projects/SR-INR
# ...

# %%
# !python layerwise_surp.py --num_iters 2000 --layer_size 50 --num_layers 10 --image_id 19 --w0 30.0
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/__init__.py:1145: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:432.)
#   _C._set_default_tensor_type(t)
# Fitting SIREN to Kodak Image19...
# Model size: 1.2kB
# Full precision bpp: 0.02
# 100%|██████████████████| 2000/2000 [00:07<00:00, 267.20it/s, best_psnr=18.7, loss=0.0134, psnr=18.7]
# Best training psnr: 18.72
# Now training model with 2 hidden layers...
# 100%|█████████████████| 2000/2000 [00:10<00:00, 192.45it/s, best_psnr=20.7, loss=0.00843, psnr=20.7]
# Best training psnr: 20.74
# Now training model with 3 hidden layers...
# 100%|█████████████████| 2000/2000 [00:13<00:00, 148.42it/s, best_psnr=21.3, loss=0.00738, psnr=21.3]
# Best training psnr: 21.32
# Now training model with 4 hidden layers...
# ...

# %% [markdown]
# ## Train on a sample image:
# Let's do image 14 for now. Layer size of 50 for now.

# %%
# !python train.py --num_iters 10000 --layer_size 50 --num_layers 10 --image_id 19 --w0 30.0
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/__init__.py:1145: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:432.)
#   _C._set_default_tensor_type(t)
# Fitting SIREN to Kodak Image19...
# Model size: 93.0kB
# Full precision bpp: 1.89
# 100%|████████████████| 10000/10000 [04:14<00:00, 39.28it/s, best_psnr=29.2, loss=0.00134, psnr=28.7]
# Best training psnr: 29.21
